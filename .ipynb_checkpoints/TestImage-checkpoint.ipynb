# %%
# !pip install scikit-image
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 13.8 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 14.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 15.6 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [scikit-image] [scikit-image]
# ...

# %%
from skimage import io
my_image = io.imread("myimage.jpg")
print(my_image)
# Out:
# [[[195 195 195]
#   [198 198 198]
#   [196 196 196]
#   ...
#   [141 141 141]
#   [133 133 133]
#   [140 140 140]]
#
#  [[191 191 191]
#   [198 198 198]
#   [202 202 202]
#   ...
#   [141 141 141]
#   [142 142 142]
#   [140 140 140]]
#
#  [[188 188 188]
#   [197 197 197]
#   [204 204 204]
#   ...
#   [143 143 143]
#   [144 144 144]
#   [132 132 132]]
#
#  ...
#
#  [[105 105 105]
#   [114 114 114]
#   [116 116 116]
#   ...
#   [161 161 161]
#   [169 169 169]
#   [172 172 172]]
#
#  [[121 121 121]
#   [121 121 121]
#   [132 132 132]
#   ...
#   [155 155 155]
#   [167 167 167]
#   [174 174 174]]
#
#  [[121 121 121]
#   [110 110 110]
#   [128 128 128]
#   ...
#   [149 149 149]
#   [159 159 159]
#   [155 155 155]]]
